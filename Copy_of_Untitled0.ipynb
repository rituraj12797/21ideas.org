# %% [markdown]
# <a href="https://colab.research.google.com/github/rituraj12797/21ideas.org/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
x= [1,3,5,8,16]
y=[2,4,6,12,10]
plt.plot(x,y)
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title(" my plot")
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras

mnist  = keras.datasets.mnist
(train_images,train_labels), (test_images,test_labels) = mnist.load_data()

plt.imshow(train_images[601],cmap = "gray")
plt.show()

model = keras.Sequential([keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(128,activation="relu"),
                          keras.layers.Dense(10,activation = "softmax")])

model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=['accuracy'])

# %%
history = model.fit(train_images,train_labels,epochs=10,validation_data = (test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 2.3594 - accuracy: 0.8423 - val_loss: 0.5585 - val_accuracy: 0.8932
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3968 - accuracy: 0.9077 - val_loss: 0.3722 - val_accuracy: 0.9131
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2845 - accuracy: 0.9291 - val_loss: 0.2871 - val_accuracy: 0.9308
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2473 - accuracy: 0.9374 - val_loss: 0.3031 - val_accuracy: 0.9355
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2325 - accuracy: 0.9421 - val_loss: 0.2575 - val_accuracy: 0.9425
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2143 - accuracy: 0.9464 - val_loss: 0.2555 - val_accuracy: 0.9439
# Epoch 7/10
# ...

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
